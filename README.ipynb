# %% [markdown]
# ![MAB Trend](Final_mab.png)

# %%
from IPython.display import HTML, display

html_content = """
<div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; max-width: 1200px; margin: 20px auto;">
    
    <div style="border: 1px solid black; padding: 20px;">
        <h3>1. Critical Vulnerability: January Collapse Pattern</h3>
        <ul>
            <li><b>January represents existential risk</b>: MAB crashes 45–55% every January (2020: -55%, 2021: -45%).</li>
            <li>Third consecutive year confirms <b>structural flaw</b>, not anomaly.</li>
            <li><b>Without intervention, January 2022 will drop MAB to 450–550 range</b> (90% confidence).</li>
        </ul>
    </div>
    
    <div style="border: 1px solid black; padding: 20px;">
        <h3>2. Peak Performance & Declining Recovery Strength</h3>
        <ul>
            <li><b>December 2020 hit ceiling at 1,361 MAB</b> — highest point under current model.</li>
            <li>Current position: 909 MAB (Feb 2021), <b>up 128% from Jan 2019 baseline</b> but highly unstable.</li>
            <li><b>Recovery momentum weakening</b>: Feb 2021 rebounded +22.5% vs Feb 2020's +131% — an <b>83% decline in recovery power</b>.</li>
        </ul>
    </div>
    
    <div style="border: 1px solid black; padding: 20px;">
        <h3>3. Seasonal Reliability & Secondary Weaknesses</h3>
        <ul>
            <li><b>Q4 (Nov–Dec) is the growth engine</b>: averages +15–20% both years — most predictable upside.</li>
            <li><b>October consistently underperforms</b>: -18% (2019), -22% (2020) — secondary vulnerability requiring Q4 prep repositioning.</li>
            <li>Volatility persists at <b>±30–40% monthly swings</b> without structural changes.</li>
        </ul>
    </div>
    
    <div style="border: 1px solid black; padding: 20px;">
        <h3>4. Strategic Imperatives — Next 90 Days</h3>
        <ul>
            <li><b>Prevent January 2022 collapse</b>: launch retention firewall by Nov 2021 (loyalty rewards, payment flexibility, Dec campaigns). Target: reduce decline from 45% to <25%.</li>
            <li><b>Build subscription revenue base</b>: pilot by April 2021, scale to 270–360 subscribers (30–40% of base) by June. Creates predictable floor and cuts volatility to ±15%.</li>
            <li><b>Accelerate recovery campaigns</b>: match Feb 2020 strength (+131%) to hit 1,100+ MAB by April 2021 — current +22% trajectory insufficient.</li>
            <li><b>Target: 1,200–1,300 sustained MAB by Q4 2021</b> with <20% monthly variance and 45–50% repeat rate.</li>
        </ul>
    </div>
    
</div>
"""

display(HTML(html_content))
# Out:
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; max-width: 1200px; margin: 20px auto;">
#
#     <div style="border: 1px solid black; padding: 20px;">
#         <h3>1. Critical Vulnerability: January Collapse Pattern</h3>
#         <ul>
#             <li><b>January represents existential risk</b>: MAB crashes 45–55% every January (2020: -55%, 2021: -45%).</li>
#             <li>Third consecutive year confirms <b>structural flaw</b>, not anomaly.</li>
#             <li><b>Without intervention, January 2022 will drop MAB to 450–550 range</b> (90% confidence).</li>
#         </ul>
#     </div>
#
#     <div style="border: 1px solid black; padding: 20px;">
#         <h3>2. Peak Performance & Declining Recovery Strength</h3>
#         <ul>
#             <li><b>December 2020 hit ceiling at 1,361 MAB</b> — highest point under current model.</li>
#             <li>Current position: 909 MAB (Feb 2021), <b>up 128% from Jan 2019 baseline</b> but highly unstable.</li>
# ...

# %% [markdown]
# Risk Assessment & Mitigation Priorities
#
# | **Risk** | **Probability** | **Impact** | **Mitigation** | **Priority** |
# |---------|------------------:|------------|----------------|:-------------|
# | **January collapse repeats (2022)** | **90%** | 🔴 **Critical** | Firewall + subscription | 🔥 **High** |
# | **Weakening recovery** | **70%** | 🔴 **High** | Strong Mar–Apr campaigns | 🔥 **High** |
# | **Peak maintenance failure** | 60% | 🟠 High | Retention + pricing | 🟡 Medium |
# | **October pattern persists** | 80% | 🟡 Medium | October turnaround strategy | 🟡 Medium |
# | **Subscription adoption <30%** | 40% | 🟡 Medium | Pilot testing + incentives | 🟡 Medium |
# | **Ongoing volatility** | 85% | 🟡 Medium | Subscription model scaling | 🟡 Medium |

# %% [markdown]
# # Revenue Per Active Customer (RPAC) Performance
#
# ## 1. Strong Growth Trajectory with 2020 Peak Achievement
# - RPAC grew **65% over two years**: from $239 (Jan 2019) to $395 (Dec 2020) — strongest monetization period on record.
# - **December 2020** marked the ceiling at $395 — highest RPAC achieved under current business model.
# - **Current position**: $293 (Feb 2021), down 26% from peak but still 23% above Jan 2019 baseline.
#
# ## 2. Critical Decline Post-Peak: Recovery Stalling
# - **January 2021** RPAC collapsed to $383 (3% below Dec 2020), but masked deeper issue: customer count crashed while high-value buyers remained.
# - **February 2021** shows true weakness: RPAC dropped to $293 (-24% MoM) as customer mix normalized and recovery failed to materialize.
# - **Pattern emerging**: post-pandemic RPAC compression suggests pricing power erosion, promotional dependency, or product mix deterioration.
#
# ## 3. Seasonal Patterns & Volatility Drivers
# - **Q4 consistently delivers premium RPAC**: Nov–Dec 2019 averaged $278, Nov–Dec 2020 averaged $362 (+30% YoY) — holiday spending and gifting drive wallet expansion.
# - **Q1 shows structural RPAC weakness**: Jan–Mar averages $20–30 below annual mean both years — budget exhaustion and promotional intensity compress margins.
# - **Mid-year stability zone**: May–Aug historically stable at $245–$300 range — represents baseline monetization capacity outside seasonal distortions.
#
# ## 4. Strategic Imperatives — Next 90 Days
# - **Diagnose Feb 2021 RPAC collapse**: investigate whether decline driven by discounting, lower-tier SKU shift, reduced basket size, or customer cohort changes. Root cause analysis by March 31.
# - **Rebuild to $320–$340 RPAC by June 2021**: requires pricing discipline, bundle optimization, and upsell mechanisms. Current $293 trajectory insufficient for H2 2021 targets.
# - **Prevent Q4 2021 RPAC degradation**: maintain $350+ RPAC during Nov–Dec or risk permanent monetization ceiling compression. Prep premium campaigns by Sept 2021.
# - **Target**: Sustained $330–$350 RPAC by Q4 2021 with controlled ±10% variance and 40%+ contribution from repeat high-value buyers (RPAC >$400).
#
# ---
#
# # Risk Assessment & Mitigation Priorities
#
# | Risk | Probability | Impact | Mitigation | Priority |
# |------|------------|--------|------------|----------|
# | RPAC compression continues (<$280) | 75% | Critical | Pricing audit + bundle strategy | High |
# | Q4 2021 fails to match 2020 peak | 65% | High | Premium campaign prep by Sept | High |
# | Promotional dependency escalates | 70% | High | Margin discipline + value tiers | High |
# | Product mix shifts to low-margin | 60% | Medium | SKU performance review + pruning | Medium |
# | Customer cohort quality declines | 55% | Medium | Acquisition channel optimization | Medium |
# | Mid-year stability breaks (<$250) | 50% | Medium | Retention + loyalty program | Medium |

# %% [markdown]
# ## Revenue Per Active Customer (RPAC) Performance
#
# | **Performance Insights** | **Strategic Imperatives** |
# |--------------------------|---------------------------|
# | **1. Strong Growth Trajectory with 2020 Peak Achievement**  <br> - RPAC grew 65% over two years: from $239 (Jan 2019) to $395 (Dec 2020). <br> - Dec 2020 marked the ceiling at $395 — highest RPAC under current business model. <br> - Current position: $293 (Feb 2021), down 26% from peak but 23% above Jan 2019 baseline. | **3. Seasonal Patterns & Volatility Drivers** <br> - Q4 delivers premium RPAC: Nov–Dec 2019 avg $278, Nov–Dec 2020 avg $362 (+30% YoY). <br> - Q1 shows structural weakness: Jan–Mar avg $20–30 below annual mean. <br> - Mid-year stability: May–Aug stable at $245–$300 — baseline monetization outside seasonal distortion. |
# | **2. Critical Decline Post-Peak: Recovery Stalling** <br> - Jan 2021 RPAC collapsed to $383 (3% below Dec 2020), but high-value buyers remained. <br> - Feb 2021 RPAC dropped to $293 (-24% MoM) as customer mix normalized. <br> - Post-pandemic RPAC compression: pricing power erosion, promotional dependency, product mix deterioration. | **4. Strategic Imperatives — Next 90 Days** <br> - Diagnose Feb 2021 RPAC collapse: investigate discounting, lower-tier SKU shift, reduced basket size, or cohort changes (by Mar 31). <br> - Rebuild to $320–$340 RPAC by June 2021: pricing discipline, bundle optimization, upsell mechanisms. <br> - Prevent Q4 2021 RPAC degradation: maintain $350+ RPAC; prep premium campaigns by Sept. <br> - Target: sustained $330–$350 RPAC by Q4 2021 with ±10% variance and 40%+ contribution from repeat high-value buyers. |
#
# ## Risk Assessment & Mitigation Priorities
#
# | **Risk** | **Probability** | **Impact** | **Mitigation** | **Priority** |
# |----------|----------------|-----------|---------------|-------------|
# | RPAC compression continues (<$280) | 75% | Critical | Pricing audit + bundle strategy | High |
# | Q4 2021 fails to match 2020 peak | 65% | High | Premium campaign prep by Sept | High |
# | Promotional dependency escalates | 70% | High | Margin discipline + value tiers | High |
# | Product mix shifts to low-margin | 60% | Medium | SKU performance review + pruning | Medium |
# | Customer cohort quality declines | 55% | Medium | Acquisition channel optimization | Medium |
# | Mid-year stability breaks (<$250) | 50% | Medium | Retention + loyalty program | Medium |
